# %% [markdown]
# ## 📊 Online Shopping Behavior Analysis Project
#
# **Objective**: Analyze purchasing trends and preferences in Pakistan through visualizations to identify improvement opportunities in:
# - Customer experience
# - Marketing strategies
# - Product management
#
# ### 🔍 Methodology
#
# 1. **Data Preparation**
#    - Library imports (Pandas, Matplotlib/Seaborn)
#    - Initial dataset loading and exploration
#
# 2. **Processing**
#    - Filtering and cleaning of key variables
#
# 3. **Visualization**
#    - Interactive/responsive graphs
#    - Comparative analysis by categories
#
# 4. **Insights**
#    - Recommendations based on detected patterns
#
# *Dataset*: Surveys of Pakistani consumers (sample: 201 people)

# %% [markdown]
# ## 1- Import of libraries, loading and general visualisation of the data

# %%
#Import of libraries
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
from wordcloud import WordCloud

# %%
#Database loading and dataframe creation
df = pd.read_csv("C:/Users/carlo/OneDrive/Documentos/Kaggle dataset/Online Shopping Data.csv")
df.head()
# Out:
#    Gender Online_Shopping_Freq Online_Purchase_Proportion Review_Check_Freq  \
# 0    Male      Rarely or Never                     0-20 %            Always
# 1  Female      Rarely or Never                     0-20 %            Always
# 2  Female      Once in a month                    41-60 %            Always
# 3    Male      Once in a month                    41-60 %            Always
# 4  Female      Rarely or Never                     0-20 %        Frequently
#
#                         Attraction_Factor  \
# 0  Ease and Comfort of shopping from home
# 1     Attractive discounts and promotions
# 2  Ease and Comfort of shopping from home
# 3  Ease and Comfort of shopping from home
# 4  Ease and Comfort of shopping from home
#
#                 Retailer_Choice_Factors                Preferred_Payment  \
# 0  Brand reputation and trustworthiness             Credit or debit card
# 1           Product reviews and ratings  Cash on delivery (if available)
# 2  Brand reputation and trustworthiness  Cash on delivery (if available)
# 3           Product reviews and ratings  Cash on delivery (if available)
# 4  Brand reputation and trustworthiness  Cash on delivery (if available)
#
#                  Local_vs_Intl_Retailers Preferred_Marketplace  \
# 0  No preference, depends on the product                 Daraz
# 1  No preference, depends on the product                Others
# 2  No preference, depends on the product                 Daraz
# 3                 Prefer local retailers            AliExpress
# 4  No preference, depends on the product                Amazon
#
#   Security_Concern_Level          Promo_Participation  \
# 0         Very concerned     Occasionally participate
# 1                Neutral  Rarely or Never participate
# 2     Somewhat concerned       Frequently participate
# 3     Somewhat concerned  Rarely or Never participate
# 4         Very concerned  Rarely or Never participate
#
#             Price_Sensitivity Comfortable_Price_Range  \
# 0  Moderately price-sensitive                1k to 5k
# 1    Slightly price-sensitive                1k to 5k
# 2  Moderately price-sensitive                1k to 5k
# 3  Moderately price-sensitive                1k to 5k
# 4  Moderately price-sensitive            less than 1k
#
#                        Frequent_Products  \
# 0       Clothing and fashion accessories
# 1       Clothing and fashion accessories
# 2       Clothing and fashion accessories
# 3       Clothing and fashion accessories
# 4  Books and media (e.g., movies, music)
#
#                              Major_Drawback  \
# 0          Yes, issues with product quality
# 1  No, I have not experienced any drawbacks
# 2          Yes, issues with product quality
# 3  No, I have not experienced any drawbacks
# 4          Yes, issues with product quality
#
#                                 Authenticity_Concern  \
# 0                                  Neutral or unsure
# 1                                  Neutral or unsure
# 2  Yes, always confident in product authenticity ...
# 3                                  Neutral or unsure
# 4  No, often concerned about product authenticity...
#
#                                 Desired_Improvements
# 0       Enhanced customer reviews and ratings system
# 1       Enhanced customer reviews and ratings system
# 2  Better product descriptions and images, Enhanc...
# 3             Better product descriptions and images
# 4  Better product descriptions and images, Improv...

# %%
df.tail()
# Out:
#      Gender     Online_Shopping_Freq Online_Purchase_Proportion  \
# 196  Female  Multiple times per week                    41-60 %
# 197    Male          Rarely or Never                    21-40 %
# 198  Female          Rarely or Never                    21-40 %
# 199  Female           Once in a week                     0-20 %
# 200   Other          Rarely or Never                     0-20 %
#
#     Review_Check_Freq                       Attraction_Factor  \
# 196      Occasionally     Attractive discounts and promotions
# 197            Always     Attractive discounts and promotions
# 198            Always  Ease and Comfort of shopping from home
# 199      Occasionally  Ease and Comfort of shopping from home
# 200      Occasionally                             Time-saving
#
#                   Retailer_Choice_Factors                Preferred_Payment  \
# 196           Product reviews and ratings  Cash on delivery (if available)
# 197           Product reviews and ratings  Cash on delivery (if available)
# 198  Brand reputation and trustworthiness  Cash on delivery (if available)
# 199                   Price and discounts  Cash on delivery (if available)
# 200  Brand reputation and trustworthiness  Cash on delivery (if available)
#
#                    Local_vs_Intl_Retailers Preferred_Marketplace  \
# 196  No preference, depends on the product                Others
# 197  No preference, depends on the product                 Daraz
# 198  No preference, depends on the product                Others
# 199  No preference, depends on the product                Others
# 200  No preference, depends on the product                Others
#
#     Security_Concern_Level                                Promo_Participation  \
# 196         Very concerned  Always take advantage of promotions and discounts
# 197         Very concerned                           Occasionally participate
# 198                Neutral                           Occasionally participate
# 199         Very concerned  Always take advantage of promotions and discounts
# 200     Somewhat concerned                        Rarely or Never participate
#
#               Price_Sensitivity Comfortable_Price_Range  \
# 196   Extremely price-sensitive                1k to 5k
# 197  Moderately price-sensitive            less than 1k
# 198  Moderately price-sensitive               5k to 10k
# 199  Moderately price-sensitive                1k to 5k
# 200    Slightly price-sensitive               5k to 10k
#
#                     Frequent_Products                          Major_Drawback  \
# 196  Clothing and fashion accessories  Yes, delayed or problematic deliveries
# 197  Clothing and fashion accessories        Yes, issues with product quality
# 198  Clothing and fashion accessories        Yes, issues with product quality
# 199  Clothing and fashion accessories        Yes, issues with product quality
# 200  Clothing and fashion accessories        Yes, issues with product quality
#
#                                   Authenticity_Concern  \
# 196  Yes, always confident in product authenticity ...
# 197         Mostly confident, with occasional concerns
# 198                                  Neutral or unsure
# 199         Mostly confident, with occasional concerns
# 200  No, often concerned about product authenticity...
#
#                                   Desired_Improvements
# 196             Better product descriptions and images
# 197  Better product descriptions and images, Improv...
# 198  Better product descriptions and images, Enhanc...
# 199                  More personalized recommendations
# 200             Better product descriptions and images

# %%
df.describe()
# Out:
#         Gender Online_Shopping_Freq Online_Purchase_Proportion  \
# count      201                  201                        201
# unique       4                    5                          5
# top     Female      Once in a month                     0-20 %
# freq       125                   99                         92
#
#        Review_Check_Freq                       Attraction_Factor  \
# count                201                                     201
# unique                 4                                       5
# top               Always  Ease and Comfort of shopping from home
# freq                 123                                      98
#
#             Retailer_Choice_Factors                Preferred_Payment  \
# count                           201                              201
# unique                            4                                4
# top     Product reviews and ratings  Cash on delivery (if available)
# freq                             85                              167
#
#                       Local_vs_Intl_Retailers Preferred_Marketplace  \
# count                                     201                   201
# unique                                      3                     4
# top     No preference, depends on the product                 Daraz
# freq                                      150                    99
#
#        Security_Concern_Level       Promo_Participation  \
# count                     201                       201
# unique                      4                         4
# top            Very concerned  Occasionally participate
# freq                      104                        67
#
#                  Price_Sensitivity Comfortable_Price_Range  \
# count                          201                     201
# unique                           4                       4
# top     Moderately price-sensitive                1k to 5k
# freq                           114                     124
#
#                        Frequent_Products                    Major_Drawback  \
# count                                201                               201
# unique                                13                                 6
# top     Clothing and fashion accessories  Yes, issues with product quality
# freq                                 114                               101
#
#                               Authenticity_Concern  \
# count                                          201
# unique                                           4
# top     Mostly confident, with occasional concerns
# freq                                            82
#
#                           Desired_Improvements
# count                                      201
# unique                                      24
# top     Better product descriptions and images
# freq                                        92

# %%
df.shape
# Out:
# (201, 17)

# %%
#Checking for null values and data type in columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Gender                      201 non-null    object
#  1   Online_Shopping_Freq        201 non-null    object
#  2   Online_Purchase_Proportion  201 non-null    object
#  3   Review_Check_Freq           201 non-null    object
#  4   Attraction_Factor           201 non-null    object
#  5   Retailer_Choice_Factors     201 non-null    object
#  6   Preferred_Payment           201 non-null    object
#  7   Local_vs_Intl_Retailers     201 non-null    object
#  8   Preferred_Marketplace       201 non-null    object
#  9   Security_Concern_Level      201 non-null    object
#  10  Promo_Participation         201 non-null    object
#  11  Price_Sensitivity           201 non-null    object
#  12  Comfortable_Price_Range     201 non-null    object
#  13  Frequent_Products           201 non-null    object
#  14  Major_Drawback              201 non-null    object
#  15  Authenticity_Concern        201 non-null    object
#  16  Desired_Improvements        201 non-null    object
# dtypes: object(17)
# memory usage: 26.8+ KB

# %%
#Checking duplicates
df.duplicated().sum()
# Out:
# 0

# %%
#Conversion of data to String type
df = df.astype("string")

# %%
#Checking for unique items in each column 
df.describe().T.plot(kind='bar')
# Out:
# <Axes: >

# %%
for columna in df.columns:
    print(f"Unique values and frequency in the column '{columna}':")
    print(df[columna].value_counts())
    print("\n")
# Out:
# Unique values and frequency in the column 'Gender':
# Gender
# Female             125
# Male                74
# 12/3/2023 21:50      1
# Other                1
# Name: count, dtype: Int64
#
#
# Unique values and frequency in the column 'Online_Shopping_Freq':
# Online_Shopping_Freq
# Once in a month            99
# Rarely or Never            72
# Once in a week             18
# Multiple times per week    11
# 12/4/2023 21:50             1
# Name: count, dtype: Int64
#
#
# Unique values and frequency in the column 'Online_Purchase_Proportion':
# Online_Purchase_Proportion
# 0-20 %     92
# 41-60 %    40
# 21-40 %    39
# 61-80%     24
# 81-100%     6
# Name: count, dtype: Int64
#
#
# Unique values and frequency in the column 'Review_Check_Freq':
# Review_Check_Freq
# Always             123
# Frequently          37
# Occasionally        24
# Rarely or Never     17
# Name: count, dtype: Int64
#
#
# Unique values and frequency in the column 'Attraction_Factor':
# Attraction_Factor
# Ease and Comfort of shopping from home    98
# Wide variety of products                  38
# Attractive discounts and promotions       36
# Time-saving                               22
# User-friendly website/app interface        7
# Name: count, dtype: Int64
#
#
# Unique values and frequency in the column 'Retailer_Choice_Factors':
# Retailer_Choice_Factors
# Product reviews and ratings             85
# Brand reputation and trustworthiness    53
# Price and discounts                     49
# Customer service and support            14
# Name: count, dtype: Int64
#
#
# Unique values and frequency in the column 'Preferred_Payment':
# Preferred_Payment
# Cash on delivery (if available)      167
# Credit or debit card                  25
# Other digital wallets                  6
# Bank transfers or direct deposits      3
# Name: count, dtype: Int64
#
#
# Unique values and frequency in the column 'Local_vs_Intl_Retailers':
# Local_vs_Intl_Retailers
# No preference, depends on the product    150
# Prefer local retailers                    32
# Prefer lnternational retailers            19
# Name: count, dtype: Int64
#
#
# Unique values and frequency in the column 'Preferred_Marketplace':
# Preferred_Marketplace
# Daraz         99
# Others        70
# Amazon        19
# AliExpress    13
# Name: count, dtype: Int64
#
#
# Unique values and frequency in the column 'Security_Concern_Level':
# Security_Concern_Level
# Very concerned          104
# Somewhat concerned       52
# Neutral                  38
# Not Concerned at all      7
# Name: count, dtype: Int64
#
#
# Unique values and frequency in the column 'Promo_Participation':
# Promo_Participation
# Occasionally participate                             67
# Rarely or Never participate                          64
# Frequently participate                               42
# Always take advantage of promotions and discounts    28
# Name: count, dtype: Int64
#
#
# Unique values and frequency in the column 'Price_Sensitivity':
# Price_Sensitivity
# Moderately price-sensitive    114
# Extremely price-sensitive      43
# Slightly price-sensitive       34
# Not price sensitive at all     10
# Name: count, dtype: Int64
#
#
# Unique values and frequency in the column 'Comfortable_Price_Range':
# Comfortable_Price_Range
# 1k to 5k         124
# 5k to 10k         42
# less than 1k      25
# more than 10k     10
# Name: count, dtype: Int64
#
#
# Unique values and frequency in the column 'Frequent_Products':
# Frequent_Products
# Clothing and fashion accessories         114
# Electronics and gadgets                   39
# Beauty and Personal care                  22
# Books and media (e.g., movies, music)     16
# Home  Appliances and furniture             2
# Clothing, Electronics, E-games             1
# Gadgets and clothing                       1
# Shoes                                      1
# Jo bhi dil mei ayega wahi lunga            1
# Fridge magnets                             1
# Foods                                      1
# Jewellery and Stationery items             1
# Sports                                     1
# Name: count, dtype: Int64
#
#
# Unique values and frequency in the column 'Major_Drawback':
# Major_Drawback
# Yes, issues with product quality                                                               101
# No, I have not experienced any drawbacks                                                        47
# Yes, delayed or problematic deliveries                                                          28
# Yes, difficulty with returns or refunds                                                         23
# Shoes                                                                                            1
# Beats ke headphone ki jagha "The Bluetooth device is ready to pair" walay headphone de diya      1
# Name: count, dtype: Int64
#
#
# Unique values and frequency in the column 'Authenticity_Concern':
# Authenticity_Concern
# Mostly confident, with occasional concerns                    82
# Neutral or unsure                                             63
# Yes, always confident in product authenticity and quality     37
# No, often concerned about product authenticity and quality    19
# Name: count, dtype: Int64
#
#
# Unique values and frequency in the column 'Desired_Improvements':
# Desired_Improvements
# Better product descriptions and images                                                                                                                                                                                                                                                                                                                            92
# Enhanced customer reviews and ratings system                                                                                                                                                                                                                                                                                                                      33
# More personalized recommendations                                                                                                                                                                                                                                                                                                                                 14
# Improved search and filtering options                                                                                                                                                                                                                                                                                                                             11
# Better product descriptions and images, Improved search and filtering options, Enhanced customer reviews and ratings system, More personalized recommendations                                                                                                                                                                                                     9
# Better product descriptions and images, Enhanced customer reviews and ratings system                                                                                                                                                                                                                                                                               8
# Better product descriptions and images, Improved search and filtering options, Enhanced customer reviews and ratings system                                                                                                                                                                                                                                        5
# Better product descriptions and images, Improved search and filtering options                                                                                                                                                                                                                                                                                      4
# Improved search and filtering options, Enhanced customer reviews and ratings system, More personalized recommendations                                                                                                                                                                                                                                             3
# Better product descriptions and images, Enhanced customer reviews and ratings system, More personalized recommendations                                                                                                                                                                                                                                            3
# Improved search and filtering options, Enhanced customer reviews and ratings system                                                                                                                                                                                                                                                                                3
# Better product descriptions and images, More personalized recommendations                                                                                                                                                                                                                                                                                          2
# Enhanced customer reviews and ratings system, More personalized recommendations                                                                                                                                                                                                                                                                                    2
# Better product descriptions and images,                                                                                                                                                                                                                                                                                                                            2
# More personalized recommendations, Customisation                                                                                                                                                                                                                                                                                                                   1
# Improved search and filtering options, More personalized recommendations,                                                                                                                                                                                                                                                                                          1
# Return option                                                                                                                                                                                                                                                                                                                                                      1
# Improved search and filtering options,                                                                                                                                                                                                                                                                                                                             1
# Pakistani ko nikalo pehle adha masla solve                                                                                                                                                                                                                                                                                                                         1
# More personalized recommendations,                                                                                                                                                                                                                                                                                                                                 1
# Better product descriptions and images, Improved search and filtering options, Enhanced customer reviews and ratings system, More personalized recommendations,                                                                                                                                                                                                    1
# Enhanced customer reviews and ratings system, They show the product quality to the customers on COD                                                                                                                                                                                                                                                                1
# Improved search and filtering options, More personalized recommendations                                                                                                                                                                                                                                                                                           1
# Better product descriptions and images, Improved search and filtering options, Enhanced customer reviews and ratings system, More personalized recommendations, It is not appropriate to overpromote a product because the attributes we were promised when we brought it home did not live up to our expectations, which made us decide not to buy it again.      1
# Name: count, dtype: Int64

# %% [markdown]
# ## 2- Data filtering

# %%
#Data filtering to remove erroneous and disposable data

df = df[df["Gender"].isin(["Male", "Female"])]
df = df[df["Major_Drawback"].isin(["Yes, issues with product quality", "No, I have not experienced any drawbacks", "Yes, delayed or problematic deliveries", "Yes, difficulty with returns or refunds"])]

# %% [markdown]
# ## 3- Graphical representation of data

# %%
#Delete in a copy the column that is not relevant for the graph to be created
df_bar = df.drop(["Desired_Improvements"], axis=1)

# %%
#Display of the columns of the dataset minus ‘Desired_Improvements’ in pie charts

plt.figure(figsize=(6,4))
for col in df_bar:
    df[col].value_counts().plot.pie(
    autopct='%1.1f%%',
    shadow=True)
    plt.title(f"Distribution according to {col}")
    plt.ylabel("")
    plt.show()

# %% [markdown]
# ## Gender-relevant line graph visualisation of relevant column columns

# %%
# Group data by "Online_Shopping_Freq" and "Gender" and count occurrences
grouped = df.groupby(['Online_Shopping_Freq', 'Gender']).size().reset_index(name='Cantidad')

# Creation of the chart
plt.figure(figsize=(8, 5))

# Iteration on each gender 
for gender in grouped['Gender'].unique():
    subset = grouped[grouped['Gender'] == gender]
    plt.plot(subset['Online_Shopping_Freq'], subset['Cantidad'], label=gender, marker='o')

# Customisation of the chart
plt.xlabel("Frequency of online shopping")
plt.ylabel("Total")
plt.title("Frequency of online shopping by Gender")
plt.legend(title="Gender")  
plt.grid(True)  
plt.tight_layout()  

plt.show()

# %%
# Group data by "Attraction_Factor" and ‘Gender’ and count occurrences
grouped = df.groupby(['Attraction_Factor', 'Gender']).size().reset_index(name='Cantidad')

# Creation of the chart
plt.figure(figsize=(8, 5))

# Iteration on each gender 
for gender in grouped['Gender'].unique():
    subset = grouped[grouped['Gender'] == gender]
    plt.plot(subset['Attraction_Factor'], subset['Cantidad'], label=gender, marker='o')

# Customisation of the chart
plt.xlabel("Attractive factors")
plt.ylabel("Total")
plt.title("Attractive factors by gender")
plt.legend(title="Gender")  
plt.grid(True)  
plt.tight_layout()  
plt.xticks(rotation=90) 

plt.show()

# %%
# Group data by "Comfortable_Price_Range" and ‘Gender’ and count occurrences
grouped = df.groupby(["Comfortable_Price_Range", "Gender"]).size().reset_index(name='Cantidad')

# Creation of the chart
plt.figure(figsize=(8, 5))

# Iteration on each gender 
for gender in grouped["Gender"].unique():
    subset = grouped[grouped["Gender"] == gender]
    plt.plot(subset["Comfortable_Price_Range"], subset["Cantidad"], label=gender, marker="o")

# Customisation of the chart
plt.xlabel("Comfortable price range")
plt.ylabel("Total")
plt.title("Comfortable price range by gender")
plt.legend(title="Gender")  
plt.grid(True)  
plt.tight_layout()  

plt.show()

# %%
# Group data by "Frequent_Products" and ‘Gender’ and count occurrences
grouped = (
    df.groupby(["Frequent_Products", "Gender"])
    .size()
    .unstack(fill_value=0)
    .stack()
    .reset_index(name="Cantidad")
)

# Creation of the chart
plt.figure(figsize=(8, 5))
for gender, subset in grouped.groupby("Gender"):
    plt.plot(subset['Frequent_Products'], subset['Cantidad'], label=gender, marker='o')

# Customisation of the chart
plt.xlabel("Frequent products")
plt.ylabel("Total")
plt.title("Frequent products bought by gender")
plt.legend(title="Gender")
plt.grid(True)
plt.tight_layout()
plt.xticks(rotation=90)

plt.show()

# %%
# Creation of a word cloud to visualise the most repeated and relevant desired improvements
# All desired improvements are merged into one string
texto = ' '.join(df["Desired_Improvements"])

# Creation of the word cloud
wordcloud = WordCloud(
    width=800,              # Ancho de la imagen
    height=400,             # Alto de la imagen
    background_color="white",  # Color de fondo
    max_words=50,           # Número máximo de palabras
    colormap="viridis"      # Mapa de colores (opcional)
).generate(texto)

# Represent the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")  
plt.title("Word cloud of desired improvements", fontsize=16,y=1)
plt.show()

# %% [markdown]
# ## 🎯 Conclusions
#
# ### Key Findings
# After visually analyzing the data, key improvement opportunities were identified:
#
# **Critical factors for sales**:
# - Product quality (top priority)
# - Detailed descriptions
# - High-quality images
#
# Customer ratings and reviews directly depend on these factors to meet expectations.
#
# ### Recommendations by Gender
# | Profile       | Main Recommendations |
# |--------------|---------------------|
# | Men          | Clothing + Electronics |
# | Women        | Beauty + Clothing |
#
# ⚠️ **Limitation**: Lack of age data prevents more personalized recommendations.
#
# ### Promotion Impact
# 68.5% of users participate in promotions → Key strategy for customer retention
